# %% [markdown]
# # Raw data exploration (Python)
#
# This notebook contains some raw data exploration done in python.  Python is convenient for this work (compared to scala) because it allows us to parse json into a dict without needing to specify types for the resulting data structure.

# %%
# note our notebook comes with a spark context
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.1.21:4043">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Reading the raw data
# Let's load the data from json into an array of dicts.  The data set isn't large; it handily fits in memory.

# %%
import glob
import os
import json
import datetime

data_dir = 'raw_data/rocdev'
files = glob.glob(data_dir + '/*/*.json')

all_data = []
samples = {}

# let's grab 10 sample values for each field
def do_sample(k, v):
    if k not in samples:
        samples[k] = []
    if len(samples[k]) <= 10:
        samples[k].append(v)
        
# loop through the files, read them as dicts
for file in files:
    with open(file, 'r') as f:
        # the channel name and date is embedded in the file name
        _, _, channel, fn = file.split('/')
        date = os.path.splitext(fn)[0]
        data = json.load(f)

        # accumulate the data and samples
        for datum in data:
            datum['channel'] = channel
            datum['date'] = date
            [do_sample(k, v) for k, v in datum.items()]
            all_data.append(datum)

# %%
# how many rows do we have?
len(all_data)
# Out:
# 168340

# %%
# what does the first row look like?
all_data[0]
# Out:
# {'type': 'message',
#  'text': 'sorry, I just spotted your reply. Yes paid account. Perhaps I don’t have the right permissions on the account. Thanks',
#  'user': 'U42EURZU4',
#  'ts': '1502724840.797357',
#  'channel': 'apple',
#  'date': '2017-08-14'}

# %% [markdown]
# Now we want to create a dataframe.  We don't have a schema, but spark can infer one if we feed it all of the json.

# %%
all_json = [json.dumps(e) for e in all_data]
df = spark.read.json(sc.parallelize(all_json))
df.printSchema()
# Out:
# root
#  |-- attachments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- actions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- confirm: struct (nullable = true)
#  |    |    |    |    |    |-- dismiss_text: string (nullable = true)
#  |    |    |    |    |    |-- ok_text: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- style: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- audio_html: string (nullable = true)
#  |    |    |-- audio_html_height: long (nullable = true)
#  |    |    |-- audio_html_width: long (nullable = true)
#  |    |    |-- author_icon: string (nullable = true)
#  |    |    |-- author_id: string (nullable = true)
#  |    |    |-- author_link: string (nullable = true)
#  |    |    |-- author_name: string (nullable = true)
#  |    |    |-- author_subname: string (nullable = true)
#  |    |    |-- callback_id: string (nullable = true)
#  |    |    |-- channel_id: string (nullable = true)
#  |    |    |-- channel_name: string (nullable = true)
#  |    |    |-- color: string (nullable = true)
#  |    |    |-- fallback: string (nullable = true)
#  |    |    |-- fields: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- short: boolean (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- files: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |-- deanimate_gif: string (nullable = true)
#  |    |    |    |    |-- display_as_bot: boolean (nullable = true)
#  |    |    |    |    |-- editable: boolean (nullable = true)
#  |    |    |    |    |-- external_type: string (nullable = true)
#  |    |    |    |    |-- filetype: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- image_exif_rotation: long (nullable = true)
#  |    |    |    |    |-- is_external: boolean (nullable = true)
#  |    |    |    |    |-- is_public: boolean (nullable = true)
#  |    |    |    |    |-- is_starred: boolean (nullable = true)
#  |    |    |    |    |-- mimetype: string (nullable = true)
#  |    |    |    |    |-- mode: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- original_h: long (nullable = true)
#  |    |    |    |    |-- original_w: long (nullable = true)
#  |    |    |    |    |-- permalink: string (nullable = true)
#  |    |    |    |    |-- permalink_public: string (nullable = true)
#  |    |    |    |    |-- pretty_type: string (nullable = true)
#  |    |    |    |    |-- public_url_shared: boolean (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- thumb_1024: string (nullable = true)
#  |    |    |    |    |-- thumb_1024_h: long (nullable = true)
#  |    |    |    |    |-- thumb_1024_w: long (nullable = true)
#  |    |    |    |    |-- thumb_160: string (nullable = true)
#  |    |    |    |    |-- thumb_360: string (nullable = true)
#  |    |    |    |    |-- thumb_360_gif: string (nullable = true)
#  |    |    |    |    |-- thumb_360_h: long (nullable = true)
#  |    |    |    |    |-- thumb_360_w: long (nullable = true)
#  |    |    |    |    |-- thumb_480: string (nullable = true)
#  |    |    |    |    |-- thumb_480_gif: string (nullable = true)
#  |    |    |    |    |-- thumb_480_h: long (nullable = true)
#  |    |    |    |    |-- thumb_480_w: long (nullable = true)
#  |    |    |    |    |-- thumb_64: string (nullable = true)
#  |    |    |    |    |-- thumb_720: string (nullable = true)
#  |    |    |    |    |-- thumb_720_h: long (nullable = true)
#  |    |    |    |    |-- thumb_720_w: long (nullable = true)
#  |    |    |    |    |-- thumb_80: string (nullable = true)
#  |    |    |    |    |-- thumb_800: string (nullable = true)
#  |    |    |    |    |-- thumb_800_h: long (nullable = true)
#  |    |    |    |    |-- thumb_800_w: long (nullable = true)
#  |    |    |    |    |-- thumb_960: string (nullable = true)
#  |    |    |    |    |-- thumb_960_h: long (nullable = true)
#  |    |    |    |    |-- thumb_960_w: long (nullable = true)
#  |    |    |    |    |-- timestamp: long (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- url_private: string (nullable = true)
#  |    |    |    |    |-- url_private_download: string (nullable = true)
#  |    |    |    |    |-- user: string (nullable = true)
#  |    |    |    |    |-- username: string (nullable = true)
#  |    |    |-- footer: string (nullable = true)
#  |    |    |-- footer_icon: string (nullable = true)
#  |    |    |-- from_hidden_wksp: boolean (nullable = true)
#  |    |    |-- from_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- image_bytes: long (nullable = true)
#  |    |    |-- image_height: long (nullable = true)
#  |    |    |-- image_url: string (nullable = true)
#  |    |    |-- image_width: long (nullable = true)
#  |    |    |-- indent: boolean (nullable = true)
#  |    |    |-- is_animated: boolean (nullable = true)
#  |    |    |-- is_msg_unfurl: boolean (nullable = true)
#  |    |    |-- is_reply_unfurl: boolean (nullable = true)
#  |    |    |-- is_share: boolean (nullable = true)
#  |    |    |-- is_thread_root_unfurl: boolean (nullable = true)
#  |    |    |-- mrkdwn_in: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- msg_subtype: string (nullable = true)
#  |    |    |-- original_url: string (nullable = true)
#  |    |    |-- service_icon: string (nullable = true)
#  |    |    |-- service_name: string (nullable = true)
#  |    |    |-- service_url: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- thumb_height: long (nullable = true)
#  |    |    |-- thumb_url: string (nullable = true)
#  |    |    |-- thumb_width: long (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- title_link: string (nullable = true)
#  |    |    |-- ts: string (nullable = true)
#  |    |    |-- video_html: string (nullable = true)
#  |    |    |-- video_html_height: string (nullable = true)
#  |    |    |-- video_html_width: string (nullable = true)
#  |    |    |-- video_url: string (nullable = true)
#  |-- bot_id: string (nullable = true)
#  |-- bot_link: string (nullable = true)
#  |-- channel: string (nullable = true)
#  |-- client_msg_id: string (nullable = true)
#  |-- comment: struct (nullable = true)
#  |    |-- comment: string (nullable = true)
#  |    |-- created: long (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- is_intro: boolean (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |    |-- user: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- display_as_bot: boolean (nullable = true)
#  |-- edited: struct (nullable = true)
#  |    |-- ts: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |-- file: struct (nullable = true)
#  |    |-- created: long (nullable = true)
#  |    |-- display_as_bot: boolean (nullable = true)
#  |    |-- edit_link: string (nullable = true)
#  |    |-- editable: boolean (nullable = true)
#  |    |-- editor: string (nullable = true)
#  |    |-- external_type: string (nullable = true)
#  |    |-- filetype: string (nullable = true)
#  |    |-- has_rich_preview: boolean (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- image_exif_rotation: long (nullable = true)
#  |    |-- is_external: boolean (nullable = true)
#  |    |-- is_public: boolean (nullable = true)
#  |    |-- last_editor: string (nullable = true)
#  |    |-- lines: long (nullable = true)
#  |    |-- lines_more: long (nullable = true)
#  |    |-- mimetype: string (nullable = true)
#  |    |-- mode: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- original_h: long (nullable = true)
#  |    |-- original_w: long (nullable = true)
#  |    |-- permalink: string (nullable = true)
#  |    |-- permalink_public: string (nullable = true)
#  |    |-- pretty_type: string (nullable = true)
#  |    |-- preview: string (nullable = true)
#  |    |-- preview_highlight: string (nullable = true)
#  |    |-- preview_is_truncated: boolean (nullable = true)
#  |    |-- public_url_shared: boolean (nullable = true)
#  |    |-- size: long (nullable = true)
#  |    |-- state: string (nullable = true)
#  |    |-- thumb_1024: string (nullable = true)
#  |    |-- thumb_1024_h: long (nullable = true)
#  |    |-- thumb_1024_w: long (nullable = true)
#  |    |-- thumb_160: string (nullable = true)
#  |    |-- thumb_360: string (nullable = true)
#  |    |-- thumb_360_h: long (nullable = true)
#  |    |-- thumb_360_w: long (nullable = true)
#  |    |-- thumb_480: string (nullable = true)
#  |    |-- thumb_480_h: long (nullable = true)
#  |    |-- thumb_480_w: long (nullable = true)
#  |    |-- thumb_64: string (nullable = true)
#  |    |-- thumb_720: string (nullable = true)
#  |    |-- thumb_720_h: long (nullable = true)
#  |    |-- thumb_720_w: long (nullable = true)
#  |    |-- thumb_80: string (nullable = true)
#  |    |-- thumb_800: string (nullable = true)
#  |    |-- thumb_800_h: long (nullable = true)
#  |    |-- thumb_800_w: long (nullable = true)
#  |    |-- thumb_960: string (nullable = true)
#  |    |-- thumb_960_h: long (nullable = true)
#  |    |-- thumb_960_w: long (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- updated: long (nullable = true)
#  |    |-- url_private: string (nullable = true)
#  |    |-- url_private_download: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |    |-- username: string (nullable = true)
#  |-- files: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- created: long (nullable = true)
#  |    |    |-- deanimate_gif: string (nullable = true)
#  |    |    |-- display_as_bot: boolean (nullable = true)
#  |    |    |-- edit_link: string (nullable = true)
#  |    |    |-- editable: boolean (nullable = true)
#  |    |    |-- editor: string (nullable = true)
#  |    |    |-- external_type: string (nullable = true)
#  |    |    |-- filetype: string (nullable = true)
#  |    |    |-- has_rich_preview: boolean (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- image_exif_rotation: long (nullable = true)
#  |    |    |-- is_external: boolean (nullable = true)
#  |    |    |-- is_public: boolean (nullable = true)
#  |    |    |-- last_editor: string (nullable = true)
#  |    |    |-- lines: long (nullable = true)
#  |    |    |-- lines_more: long (nullable = true)
#  |    |    |-- mimetype: string (nullable = true)
#  |    |    |-- mode: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- original_h: long (nullable = true)
#  |    |    |-- original_w: long (nullable = true)
#  |    |    |-- permalink: string (nullable = true)
#  |    |    |-- permalink_public: string (nullable = true)
#  |    |    |-- pretty_type: string (nullable = true)
#  |    |    |-- preview: string (nullable = true)
#  |    |    |-- preview_highlight: string (nullable = true)
#  |    |    |-- preview_is_truncated: boolean (nullable = true)
#  |    |    |-- public_url_shared: boolean (nullable = true)
#  |    |    |-- reactions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- count: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- users: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- thumb_1024: string (nullable = true)
#  |    |    |-- thumb_1024_h: long (nullable = true)
#  |    |    |-- thumb_1024_w: long (nullable = true)
#  |    |    |-- thumb_160: string (nullable = true)
#  |    |    |-- thumb_360: string (nullable = true)
#  |    |    |-- thumb_360_gif: string (nullable = true)
#  |    |    |-- thumb_360_h: long (nullable = true)
#  |    |    |-- thumb_360_w: long (nullable = true)
#  |    |    |-- thumb_480: string (nullable = true)
#  |    |    |-- thumb_480_gif: string (nullable = true)
#  |    |    |-- thumb_480_h: long (nullable = true)
#  |    |    |-- thumb_480_w: long (nullable = true)
#  |    |    |-- thumb_64: string (nullable = true)
#  |    |    |-- thumb_720: string (nullable = true)
#  |    |    |-- thumb_720_h: long (nullable = true)
#  |    |    |-- thumb_720_w: long (nullable = true)
#  |    |    |-- thumb_80: string (nullable = true)
#  |    |    |-- thumb_800: string (nullable = true)
#  |    |    |-- thumb_800_h: long (nullable = true)
#  |    |    |-- thumb_800_w: long (nullable = true)
#  |    |    |-- thumb_960: string (nullable = true)
#  |    |    |-- thumb_960_h: long (nullable = true)
#  |    |    |-- thumb_960_w: long (nullable = true)
#  |    |    |-- thumb_pdf: string (nullable = true)
#  |    |    |-- thumb_pdf_h: long (nullable = true)
#  |    |    |-- thumb_pdf_w: long (nullable = true)
#  |    |    |-- thumb_video: string (nullable = true)
#  |    |    |-- timestamp: long (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated: long (nullable = true)
#  |    |    |-- url_private: string (nullable = true)
#  |    |    |-- url_private_download: string (nullable = true)
#  |    |    |-- user: string (nullable = true)
#  |    |    |-- username: string (nullable = true)
#  |-- hidden: boolean (nullable = true)
#  |-- icons: struct (nullable = true)
#  |    |-- image_36: string (nullable = true)
#  |    |-- image_48: string (nullable = true)
#  |    |-- image_72: string (nullable = true)
#  |-- inviter: string (nullable = true)
#  |-- is_intro: boolean (nullable = true)
#  |-- item: struct (nullable = true)
#  |    |-- comment: string (nullable = true)
#  |    |-- created: long (nullable = true)
#  |    |-- display_as_bot: boolean (nullable = true)
#  |    |-- editable: boolean (nullable = true)
#  |    |-- editor: string (nullable = true)
#  |    |-- external_type: string (nullable = true)
#  |    |-- filetype: string (nullable = true)
#  |    |-- has_rich_preview: boolean (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- image_exif_rotation: long (nullable = true)
#  |    |-- is_external: boolean (nullable = true)
#  |    |-- is_intro: boolean (nullable = true)
#  |    |-- is_public: boolean (nullable = true)
#  |    |-- last_editor: string (nullable = true)
#  |    |-- mimetype: string (nullable = true)
#  |    |-- mode: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- original_h: long (nullable = true)
#  |    |-- original_w: long (nullable = true)
#  |    |-- permalink: string (nullable = true)
#  |    |-- permalink_public: string (nullable = true)
#  |    |-- pretty_type: string (nullable = true)
#  |    |-- preview: string (nullable = true)
#  |    |-- public_url_shared: boolean (nullable = true)
#  |    |-- size: long (nullable = true)
#  |    |-- state: string (nullable = true)
#  |    |-- thumb_160: string (nullable = true)
#  |    |-- thumb_360: string (nullable = true)
#  |    |-- thumb_360_h: long (nullable = true)
#  |    |-- thumb_360_w: long (nullable = true)
#  |    |-- thumb_480: string (nullable = true)
#  |    |-- thumb_480_h: long (nullable = true)
#  |    |-- thumb_480_w: long (nullable = true)
#  |    |-- thumb_64: string (nullable = true)
#  |    |-- thumb_720: string (nullable = true)
#  |    |-- thumb_720_h: long (nullable = true)
#  |    |-- thumb_720_w: long (nullable = true)
#  |    |-- thumb_80: string (nullable = true)
#  |    |-- thumb_800: string (nullable = true)
#  |    |-- thumb_800_h: long (nullable = true)
#  |    |-- thumb_800_w: long (nullable = true)
#  |    |-- thumb_pdf: string (nullable = true)
#  |    |-- thumb_pdf_h: long (nullable = true)
#  |    |-- thumb_pdf_w: long (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- updated: long (nullable = true)
#  |    |-- url_private: string (nullable = true)
#  |    |-- url_private_download: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |    |-- username: string (nullable = true)
#  |-- item_type: string (nullable = true)
#  |-- latest_reply: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- new_broadcast: boolean (nullable = true)
#  |-- old_name: string (nullable = true)
#  |-- parent_user_id: string (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- reactions: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- count: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- users: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |-- replies: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- ts: string (nullable = true)
#  |    |    |-- user: string (nullable = true)
#  |-- reply_count: long (nullable = true)
#  |-- reply_users: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- reply_users_count: long (nullable = true)
#  |-- root: struct (nullable = true)
#  |    |-- attachments: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- audio_html: string (nullable = true)
#  |    |    |    |-- audio_html_height: long (nullable = true)
#  |    |    |    |-- audio_html_width: long (nullable = true)
#  |    |    |    |-- author_icon: string (nullable = true)
#  |    |    |    |-- author_id: string (nullable = true)
#  |    |    |    |-- author_link: string (nullable = true)
#  |    |    |    |-- author_name: string (nullable = true)
#  |    |    |    |-- author_subname: string (nullable = true)
#  |    |    |    |-- channel_id: string (nullable = true)
#  |    |    |    |-- channel_name: string (nullable = true)
#  |    |    |    |-- color: string (nullable = true)
#  |    |    |    |-- fallback: string (nullable = true)
#  |    |    |    |-- fields: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- short: boolean (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- footer: string (nullable = true)
#  |    |    |    |-- footer_icon: string (nullable = true)
#  |    |    |    |-- from_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- image_bytes: long (nullable = true)
#  |    |    |    |-- image_height: long (nullable = true)
#  |    |    |    |-- image_url: string (nullable = true)
#  |    |    |    |-- image_width: long (nullable = true)
#  |    |    |    |-- indent: boolean (nullable = true)
#  |    |    |    |-- is_animated: boolean (nullable = true)
#  |    |    |    |-- is_msg_unfurl: boolean (nullable = true)
#  |    |    |    |-- mrkdwn_in: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- original_url: string (nullable = true)
#  |    |    |    |-- service_icon: string (nullable = true)
#  |    |    |    |-- service_name: string (nullable = true)
#  |    |    |    |-- service_url: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- thumb_height: long (nullable = true)
#  |    |    |    |-- thumb_url: string (nullable = true)
#  |    |    |    |-- thumb_width: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- title_link: string (nullable = true)
#  |    |    |    |-- ts: string (nullable = true)
#  |    |    |    |-- video_html: string (nullable = true)
#  |    |    |    |-- video_html_height: long (nullable = true)
#  |    |    |    |-- video_html_width: long (nullable = true)
#  |    |-- bot_id: string (nullable = true)
#  |    |-- client_msg_id: string (nullable = true)
#  |    |-- display_as_bot: boolean (nullable = true)
#  |    |-- edited: struct (nullable = true)
#  |    |    |-- ts: string (nullable = true)
#  |    |    |-- user: string (nullable = true)
#  |    |-- files: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- display_as_bot: boolean (nullable = true)
#  |    |    |    |-- editable: boolean (nullable = true)
#  |    |    |    |-- external_type: string (nullable = true)
#  |    |    |    |-- filetype: string (nullable = true)
#  |    |    |    |-- has_rich_preview: boolean (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- image_exif_rotation: long (nullable = true)
#  |    |    |    |-- is_external: boolean (nullable = true)
#  |    |    |    |-- is_public: boolean (nullable = true)
#  |    |    |    |-- mimetype: string (nullable = true)
#  |    |    |    |-- mode: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- original_h: long (nullable = true)
#  |    |    |    |-- original_w: long (nullable = true)
#  |    |    |    |-- permalink: string (nullable = true)
#  |    |    |    |-- permalink_public: string (nullable = true)
#  |    |    |    |-- pretty_type: string (nullable = true)
#  |    |    |    |-- public_url_shared: boolean (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- thumb_1024: string (nullable = true)
#  |    |    |    |-- thumb_1024_h: long (nullable = true)
#  |    |    |    |-- thumb_1024_w: long (nullable = true)
#  |    |    |    |-- thumb_160: string (nullable = true)
#  |    |    |    |-- thumb_360: string (nullable = true)
#  |    |    |    |-- thumb_360_h: long (nullable = true)
#  |    |    |    |-- thumb_360_w: long (nullable = true)
#  |    |    |    |-- thumb_480: string (nullable = true)
#  |    |    |    |-- thumb_480_h: long (nullable = true)
#  |    |    |    |-- thumb_480_w: long (nullable = true)
#  |    |    |    |-- thumb_64: string (nullable = true)
#  |    |    |    |-- thumb_720: string (nullable = true)
#  |    |    |    |-- thumb_720_h: long (nullable = true)
#  |    |    |    |-- thumb_720_w: long (nullable = true)
#  |    |    |    |-- thumb_80: string (nullable = true)
#  |    |    |    |-- thumb_800: string (nullable = true)
#  |    |    |    |-- thumb_800_h: long (nullable = true)
#  |    |    |    |-- thumb_800_w: long (nullable = true)
#  |    |    |    |-- thumb_960: string (nullable = true)
#  |    |    |    |-- thumb_960_h: long (nullable = true)
#  |    |    |    |-- thumb_960_w: long (nullable = true)
#  |    |    |    |-- timestamp: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url_private: string (nullable = true)
#  |    |    |    |-- url_private_download: string (nullable = true)
#  |    |    |    |-- user: string (nullable = true)
#  |    |    |    |-- username: string (nullable = true)
#  |    |-- hidden: boolean (nullable = true)
#  |    |-- icons: struct (nullable = true)
#  |    |    |-- image_36: string (nullable = true)
#  |    |    |-- image_48: string (nullable = true)
#  |    |    |-- image_72: string (nullable = true)
#  |    |-- latest_reply: string (nullable = true)
#  |    |-- replies: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ts: string (nullable = true)
#  |    |    |    |-- user: string (nullable = true)
#  |    |-- reply_count: long (nullable = true)
#  |    |-- reply_users: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- reply_users_count: long (nullable = true)
#  |    |-- subtype: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |    |-- thread_ts: string (nullable = true)
#  |    |-- ts: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- upload: boolean (nullable = true)
#  |    |-- upload_reply_to: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |    |-- username: string (nullable = true)
#  |-- subtype: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- thread_ts: string (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- ts: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- upload: boolean (nullable = true)
#  |-- upload_reply_to: string (nullable = true)
#  |-- user: string (nullable = true)
#  |-- username: string (nullable = true)

# %% [markdown]
# Well that's gnarly, but it'll work for now.  If we wanted to make this a production system, we might want to put some more effort into finding a better schema to represent this data.

# %%
# just to illustrate some pyspark functionality, let's find the top channels
from pyspark.sql import functions as F
df\
    .groupBy('channel')\
    .count()\
    .select('channel', 'count')\
    .sort(F.col('count').desc())\
    .show()
# Out:
# +-----------------+-----+
# |          channel|count|
# +-----------------+-----+
# |          general|71493|
# |          careers|16418|
# |        mentoring| 9293|
# |         politics| 6754|
# |          paychex| 5639|
# |       javascript| 5158|
# |         security| 4267|
# |           gaming| 3910|
# |   remote-workers| 2839|
# |american-football| 2777|
# |           devops| 2602|
# |           python| 2440|
# |              git| 2397|
# |           random| 2362|
# |             food| 2138|
# |              www| 1897|
# |           status| 1632|
# |fakeinternetmoney| 1542|
# |   ethics-in-tech| 1496|
# |           dotnet| 1424|
# +-----------------+-----+
# only showing top 20 rows

# %% [markdown]
# We can execute spark sql on a dataframe by registering it as a temp view.

# %%
df.createOrReplaceTempView("events")

spark.sql("select channel, count(1) as count from events group by channel order by count desc").show()
# Out:
# +-----------------+-----+
# |          channel|count|
# +-----------------+-----+
# |          general|71493|
# |          careers|16418|
# |        mentoring| 9293|
# |         politics| 6754|
# |          paychex| 5639|
# |       javascript| 5158|
# |         security| 4267|
# |           gaming| 3910|
# |   remote-workers| 2839|
# |american-football| 2777|
# |           devops| 2602|
# |           python| 2440|
# |              git| 2397|
# |           random| 2362|
# |             food| 2138|
# |              www| 1897|
# |           status| 1632|
# |fakeinternetmoney| 1542|
# |   ethics-in-tech| 1496|
# |           dotnet| 1424|
# +-----------------+-----+
# only showing top 20 rows
