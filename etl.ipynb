# %% [markdown]
# # ETL Notebook
#
# Loads the raw json data and writes it out as parquet.  NOTE this will overwrite any existing parquet data.

# %%
# import the etl module
from tailor import etl

# %%
# load the events, show how many records we loaded
events_df = etl.load_events(spark, 'raw_data/rocdev')
events_df.count()
# Out:
# 168340

# %%
# clear out any existing parquet event data
# !rm -rf parquet_data/rocdev/events.parquet
# !mkdir -p parquet_data/rocdev

# %% [markdown]
# We write to [parquet](https://parquet.apache.org/) format, which is a binary format that is fairly common for spark.
#
# Parquet + Spark supports [partitioning](https://en.wikipedia.org/wiki/Partition_(database)) and if this were an ETL process for a larger-scale system, we would probably want to partition by date (and maybe channel) so that we could incrementally load/reload data.  To partition this data, we would simply need to change the line below to `events_df.write.partitionBy("date").parquet(...)`.  For this small data set, which is fairly sparse when looked at date-over-date, partitioning by date actually leads to very inefficient storage (500MB vs 25MB!).

# %%
# write the event parquet
events_df.write.parquet('parquet_data/rocdev/events.parquet')

# %%
# let's see what the output looks like on disk
# !ls -lah parquet_data/rocdev/events.parquet | head -n 20
# Out:
# total 50576
# drwxr-xr-x  20 dswain  staff   640B Apr  1 10:26 .
# drwxr-xr-x   5 dswain  staff   160B Apr  1 10:26 ..
# -rw-r--r--   1 dswain  staff     8B Apr  1 10:26 ._SUCCESS.crc
# -rw-r--r--   1 dswain  staff    20K Apr  1 10:26 .part-00000-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet.crc
# -rw-r--r--   1 dswain  staff    23K Apr  1 10:26 .part-00001-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet.crc
# -rw-r--r--   1 dswain  staff    21K Apr  1 10:26 .part-00002-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet.crc
# -rw-r--r--   1 dswain  staff    22K Apr  1 10:26 .part-00003-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet.crc
# -rw-r--r--   1 dswain  staff    21K Apr  1 10:26 .part-00004-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet.crc
# -rw-r--r--   1 dswain  staff    23K Apr  1 10:26 .part-00005-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet.crc
# -rw-r--r--   1 dswain  staff    24K Apr  1 10:26 .part-00006-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet.crc
# -rw-r--r--   1 dswain  staff    21K Apr  1 10:26 .part-00007-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet.crc
# -rw-r--r--   1 dswain  staff     0B Apr  1 10:26 _SUCCESS
# -rw-r--r--   1 dswain  staff   2.5M Apr  1 10:26 part-00000-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet
# -rw-r--r--   1 dswain  staff   2.9M Apr  1 10:26 part-00001-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet
# -rw-r--r--   1 dswain  staff   2.6M Apr  1 10:26 part-00002-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet
# -rw-r--r--   1 dswain  staff   2.8M Apr  1 10:26 part-00003-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet
# -rw-r--r--   1 dswain  staff   2.7M Apr  1 10:26 part-00004-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet
# -rw-r--r--   1 dswain  staff   2.8M Apr  1 10:26 part-00005-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet
# -rw-r--r--   1 dswain  staff   3.0M Apr  1 10:26 part-00006-37207290-68ad-46df-b104-7cc85b94d1b9-c000.snappy.parquet

# %%
# how much disk space does this use?
# !du -h -d 0 raw_data/rocdev
# !du -h -d 1 parquet_data/rocdev
# Out:
#  89M	raw_data/rocdev
# 484K	parquet_data/rocdev/users.parquet
#  25M	parquet_data/rocdev/events.parquet
# 136K	parquet_data/rocdev/channels.parquet
#  25M	parquet_data/rocdev

# %%
# load the user data
users_df = etl.load_users(spark, 'raw_data/rocdev')

# %%
# make space for user parquet
# !rm -rf parquet_data/rocdev/users.parquet
# !mkdir -p parquet_data/rocdev/

# %%
# write user parquet
users_df.write.parquet('parquet_data/rocdev/users.parquet')

# %%
# lather, rinse, repeat with channels
channels_df = etl.load_channels(spark, 'raw_data/rocdev')

# %%
# !rm -rf parquet_data/rocdev/channels.parquet
# !mkdir -p parquet_data/rocdev/

# %%
channels_df.write.parquet('parquet_data/rocdev/channels.parquet')

# %%
# !du -h -d 1 parquet_data/rocdev
# Out:
# 484K	parquet_data/rocdev/users.parquet
#  25M	parquet_data/rocdev/events.parquet
# 136K	parquet_data/rocdev/channels.parquet
#  25M	parquet_data/rocdev

# %%
# let's read back the events just as a sanity check
df = spark.read.parquet('parquet_data/rocdev/events.parquet')
df.count()
# Out:
# 168340

# %%
# what does the schema look like?
df.printSchema()
# Out:
# root
#  |-- attachments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- actions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- confirm: struct (nullable = true)
#  |    |    |    |    |    |-- dismiss_text: string (nullable = true)
#  |    |    |    |    |    |-- ok_text: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- style: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- audio_html: string (nullable = true)
#  |    |    |-- audio_html_height: long (nullable = true)
#  |    |    |-- audio_html_width: long (nullable = true)
#  |    |    |-- author_icon: string (nullable = true)
#  |    |    |-- author_id: string (nullable = true)
#  |    |    |-- author_link: string (nullable = true)
#  |    |    |-- author_name: string (nullable = true)
#  |    |    |-- author_subname: string (nullable = true)
#  |    |    |-- callback_id: string (nullable = true)
#  |    |    |-- channel_id: string (nullable = true)
#  |    |    |-- channel_name: string (nullable = true)
#  |    |    |-- color: string (nullable = true)
#  |    |    |-- fallback: string (nullable = true)
#  |    |    |-- fields: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- short: boolean (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- value: string (nullable = true)
#  |    |    |-- files: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |-- deanimate_gif: string (nullable = true)
#  |    |    |    |    |-- display_as_bot: boolean (nullable = true)
#  |    |    |    |    |-- editable: boolean (nullable = true)
#  |    |    |    |    |-- external_type: string (nullable = true)
#  |    |    |    |    |-- filetype: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- image_exif_rotation: long (nullable = true)
#  |    |    |    |    |-- is_external: boolean (nullable = true)
#  |    |    |    |    |-- is_public: boolean (nullable = true)
#  |    |    |    |    |-- is_starred: boolean (nullable = true)
#  |    |    |    |    |-- mimetype: string (nullable = true)
#  |    |    |    |    |-- mode: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- original_h: long (nullable = true)
#  |    |    |    |    |-- original_w: long (nullable = true)
#  |    |    |    |    |-- permalink: string (nullable = true)
#  |    |    |    |    |-- permalink_public: string (nullable = true)
#  |    |    |    |    |-- pretty_type: string (nullable = true)
#  |    |    |    |    |-- public_url_shared: boolean (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- thumb_1024: string (nullable = true)
#  |    |    |    |    |-- thumb_1024_h: long (nullable = true)
#  |    |    |    |    |-- thumb_1024_w: long (nullable = true)
#  |    |    |    |    |-- thumb_160: string (nullable = true)
#  |    |    |    |    |-- thumb_360: string (nullable = true)
#  |    |    |    |    |-- thumb_360_gif: string (nullable = true)
#  |    |    |    |    |-- thumb_360_h: long (nullable = true)
#  |    |    |    |    |-- thumb_360_w: long (nullable = true)
#  |    |    |    |    |-- thumb_480: string (nullable = true)
#  |    |    |    |    |-- thumb_480_gif: string (nullable = true)
#  |    |    |    |    |-- thumb_480_h: long (nullable = true)
#  |    |    |    |    |-- thumb_480_w: long (nullable = true)
#  |    |    |    |    |-- thumb_64: string (nullable = true)
#  |    |    |    |    |-- thumb_720: string (nullable = true)
#  |    |    |    |    |-- thumb_720_h: long (nullable = true)
#  |    |    |    |    |-- thumb_720_w: long (nullable = true)
#  |    |    |    |    |-- thumb_80: string (nullable = true)
#  |    |    |    |    |-- thumb_800: string (nullable = true)
#  |    |    |    |    |-- thumb_800_h: long (nullable = true)
#  |    |    |    |    |-- thumb_800_w: long (nullable = true)
#  |    |    |    |    |-- thumb_960: string (nullable = true)
#  |    |    |    |    |-- thumb_960_h: long (nullable = true)
#  |    |    |    |    |-- thumb_960_w: long (nullable = true)
#  |    |    |    |    |-- timestamp: long (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- url_private: string (nullable = true)
#  |    |    |    |    |-- url_private_download: string (nullable = true)
#  |    |    |    |    |-- user: string (nullable = true)
#  |    |    |    |    |-- username: string (nullable = true)
#  |    |    |-- footer: string (nullable = true)
#  |    |    |-- footer_icon: string (nullable = true)
#  |    |    |-- from_hidden_wksp: boolean (nullable = true)
#  |    |    |-- from_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- image_bytes: long (nullable = true)
#  |    |    |-- image_height: long (nullable = true)
#  |    |    |-- image_url: string (nullable = true)
#  |    |    |-- image_width: long (nullable = true)
#  |    |    |-- indent: boolean (nullable = true)
#  |    |    |-- is_animated: boolean (nullable = true)
#  |    |    |-- is_msg_unfurl: boolean (nullable = true)
#  |    |    |-- is_reply_unfurl: boolean (nullable = true)
#  |    |    |-- is_share: boolean (nullable = true)
#  |    |    |-- is_thread_root_unfurl: boolean (nullable = true)
#  |    |    |-- mrkdwn_in: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- msg_subtype: string (nullable = true)
#  |    |    |-- original_url: string (nullable = true)
#  |    |    |-- service_icon: string (nullable = true)
#  |    |    |-- service_name: string (nullable = true)
#  |    |    |-- service_url: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |    |    |-- thumb_height: long (nullable = true)
#  |    |    |-- thumb_url: string (nullable = true)
#  |    |    |-- thumb_width: long (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- title_link: string (nullable = true)
#  |    |    |-- ts: string (nullable = true)
#  |    |    |-- video_html: string (nullable = true)
#  |    |    |-- video_html_height: string (nullable = true)
#  |    |    |-- video_html_width: string (nullable = true)
#  |    |    |-- video_url: string (nullable = true)
#  |-- bot_id: string (nullable = true)
#  |-- bot_link: string (nullable = true)
#  |-- channel: string (nullable = true)
#  |-- client_msg_id: string (nullable = true)
#  |-- comment: struct (nullable = true)
#  |    |-- comment: string (nullable = true)
#  |    |-- created: long (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- is_intro: boolean (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |    |-- user: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- display_as_bot: boolean (nullable = true)
#  |-- edited: struct (nullable = true)
#  |    |-- ts: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |-- file: struct (nullable = true)
#  |    |-- created: long (nullable = true)
#  |    |-- display_as_bot: boolean (nullable = true)
#  |    |-- edit_link: string (nullable = true)
#  |    |-- editable: boolean (nullable = true)
#  |    |-- editor: string (nullable = true)
#  |    |-- external_type: string (nullable = true)
#  |    |-- filetype: string (nullable = true)
#  |    |-- has_rich_preview: boolean (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- image_exif_rotation: long (nullable = true)
#  |    |-- is_external: boolean (nullable = true)
#  |    |-- is_public: boolean (nullable = true)
#  |    |-- last_editor: string (nullable = true)
#  |    |-- lines: long (nullable = true)
#  |    |-- lines_more: long (nullable = true)
#  |    |-- mimetype: string (nullable = true)
#  |    |-- mode: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- original_h: long (nullable = true)
#  |    |-- original_w: long (nullable = true)
#  |    |-- permalink: string (nullable = true)
#  |    |-- permalink_public: string (nullable = true)
#  |    |-- pretty_type: string (nullable = true)
#  |    |-- preview: string (nullable = true)
#  |    |-- preview_highlight: string (nullable = true)
#  |    |-- preview_is_truncated: boolean (nullable = true)
#  |    |-- public_url_shared: boolean (nullable = true)
#  |    |-- size: long (nullable = true)
#  |    |-- state: string (nullable = true)
#  |    |-- thumb_1024: string (nullable = true)
#  |    |-- thumb_1024_h: long (nullable = true)
#  |    |-- thumb_1024_w: long (nullable = true)
#  |    |-- thumb_160: string (nullable = true)
#  |    |-- thumb_360: string (nullable = true)
#  |    |-- thumb_360_h: long (nullable = true)
#  |    |-- thumb_360_w: long (nullable = true)
#  |    |-- thumb_480: string (nullable = true)
#  |    |-- thumb_480_h: long (nullable = true)
#  |    |-- thumb_480_w: long (nullable = true)
#  |    |-- thumb_64: string (nullable = true)
#  |    |-- thumb_720: string (nullable = true)
#  |    |-- thumb_720_h: long (nullable = true)
#  |    |-- thumb_720_w: long (nullable = true)
#  |    |-- thumb_80: string (nullable = true)
#  |    |-- thumb_800: string (nullable = true)
#  |    |-- thumb_800_h: long (nullable = true)
#  |    |-- thumb_800_w: long (nullable = true)
#  |    |-- thumb_960: string (nullable = true)
#  |    |-- thumb_960_h: long (nullable = true)
#  |    |-- thumb_960_w: long (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- updated: long (nullable = true)
#  |    |-- url_private: string (nullable = true)
#  |    |-- url_private_download: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |    |-- username: string (nullable = true)
#  |-- files: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- created: long (nullable = true)
#  |    |    |-- deanimate_gif: string (nullable = true)
#  |    |    |-- display_as_bot: boolean (nullable = true)
#  |    |    |-- edit_link: string (nullable = true)
#  |    |    |-- editable: boolean (nullable = true)
#  |    |    |-- editor: string (nullable = true)
#  |    |    |-- external_type: string (nullable = true)
#  |    |    |-- filetype: string (nullable = true)
#  |    |    |-- has_rich_preview: boolean (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- image_exif_rotation: long (nullable = true)
#  |    |    |-- is_external: boolean (nullable = true)
#  |    |    |-- is_public: boolean (nullable = true)
#  |    |    |-- last_editor: string (nullable = true)
#  |    |    |-- lines: long (nullable = true)
#  |    |    |-- lines_more: long (nullable = true)
#  |    |    |-- mimetype: string (nullable = true)
#  |    |    |-- mode: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- original_h: long (nullable = true)
#  |    |    |-- original_w: long (nullable = true)
#  |    |    |-- permalink: string (nullable = true)
#  |    |    |-- permalink_public: string (nullable = true)
#  |    |    |-- pretty_type: string (nullable = true)
#  |    |    |-- preview: string (nullable = true)
#  |    |    |-- preview_highlight: string (nullable = true)
#  |    |    |-- preview_is_truncated: boolean (nullable = true)
#  |    |    |-- public_url_shared: boolean (nullable = true)
#  |    |    |-- reactions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- count: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- users: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- thumb_1024: string (nullable = true)
#  |    |    |-- thumb_1024_h: long (nullable = true)
#  |    |    |-- thumb_1024_w: long (nullable = true)
#  |    |    |-- thumb_160: string (nullable = true)
#  |    |    |-- thumb_360: string (nullable = true)
#  |    |    |-- thumb_360_gif: string (nullable = true)
#  |    |    |-- thumb_360_h: long (nullable = true)
#  |    |    |-- thumb_360_w: long (nullable = true)
#  |    |    |-- thumb_480: string (nullable = true)
#  |    |    |-- thumb_480_gif: string (nullable = true)
#  |    |    |-- thumb_480_h: long (nullable = true)
#  |    |    |-- thumb_480_w: long (nullable = true)
#  |    |    |-- thumb_64: string (nullable = true)
#  |    |    |-- thumb_720: string (nullable = true)
#  |    |    |-- thumb_720_h: long (nullable = true)
#  |    |    |-- thumb_720_w: long (nullable = true)
#  |    |    |-- thumb_80: string (nullable = true)
#  |    |    |-- thumb_800: string (nullable = true)
#  |    |    |-- thumb_800_h: long (nullable = true)
#  |    |    |-- thumb_800_w: long (nullable = true)
#  |    |    |-- thumb_960: string (nullable = true)
#  |    |    |-- thumb_960_h: long (nullable = true)
#  |    |    |-- thumb_960_w: long (nullable = true)
#  |    |    |-- thumb_pdf: string (nullable = true)
#  |    |    |-- thumb_pdf_h: long (nullable = true)
#  |    |    |-- thumb_pdf_w: long (nullable = true)
#  |    |    |-- thumb_video: string (nullable = true)
#  |    |    |-- timestamp: long (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated: long (nullable = true)
#  |    |    |-- url_private: string (nullable = true)
#  |    |    |-- url_private_download: string (nullable = true)
#  |    |    |-- user: string (nullable = true)
#  |    |    |-- username: string (nullable = true)
#  |-- hidden: boolean (nullable = true)
#  |-- icons: struct (nullable = true)
#  |    |-- image_36: string (nullable = true)
#  |    |-- image_48: string (nullable = true)
#  |    |-- image_72: string (nullable = true)
#  |-- inviter: string (nullable = true)
#  |-- is_intro: boolean (nullable = true)
#  |-- item: struct (nullable = true)
#  |    |-- comment: string (nullable = true)
#  |    |-- created: long (nullable = true)
#  |    |-- display_as_bot: boolean (nullable = true)
#  |    |-- editable: boolean (nullable = true)
#  |    |-- editor: string (nullable = true)
#  |    |-- external_type: string (nullable = true)
#  |    |-- filetype: string (nullable = true)
#  |    |-- has_rich_preview: boolean (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- image_exif_rotation: long (nullable = true)
#  |    |-- is_external: boolean (nullable = true)
#  |    |-- is_intro: boolean (nullable = true)
#  |    |-- is_public: boolean (nullable = true)
#  |    |-- last_editor: string (nullable = true)
#  |    |-- mimetype: string (nullable = true)
#  |    |-- mode: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- original_h: long (nullable = true)
#  |    |-- original_w: long (nullable = true)
#  |    |-- permalink: string (nullable = true)
#  |    |-- permalink_public: string (nullable = true)
#  |    |-- pretty_type: string (nullable = true)
#  |    |-- preview: string (nullable = true)
#  |    |-- public_url_shared: boolean (nullable = true)
#  |    |-- size: long (nullable = true)
#  |    |-- state: string (nullable = true)
#  |    |-- thumb_160: string (nullable = true)
#  |    |-- thumb_360: string (nullable = true)
#  |    |-- thumb_360_h: long (nullable = true)
#  |    |-- thumb_360_w: long (nullable = true)
#  |    |-- thumb_480: string (nullable = true)
#  |    |-- thumb_480_h: long (nullable = true)
#  |    |-- thumb_480_w: long (nullable = true)
#  |    |-- thumb_64: string (nullable = true)
#  |    |-- thumb_720: string (nullable = true)
#  |    |-- thumb_720_h: long (nullable = true)
#  |    |-- thumb_720_w: long (nullable = true)
#  |    |-- thumb_80: string (nullable = true)
#  |    |-- thumb_800: string (nullable = true)
#  |    |-- thumb_800_h: long (nullable = true)
#  |    |-- thumb_800_w: long (nullable = true)
#  |    |-- thumb_pdf: string (nullable = true)
#  |    |-- thumb_pdf_h: long (nullable = true)
#  |    |-- thumb_pdf_w: long (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- updated: long (nullable = true)
#  |    |-- url_private: string (nullable = true)
#  |    |-- url_private_download: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |    |-- username: string (nullable = true)
#  |-- item_type: string (nullable = true)
#  |-- latest_reply: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- new_broadcast: boolean (nullable = true)
#  |-- old_name: string (nullable = true)
#  |-- parent_user_id: string (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- reactions: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- count: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- users: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |-- replies: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- ts: string (nullable = true)
#  |    |    |-- user: string (nullable = true)
#  |-- reply_count: long (nullable = true)
#  |-- reply_users: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- reply_users_count: long (nullable = true)
#  |-- root: struct (nullable = true)
#  |    |-- attachments: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- audio_html: string (nullable = true)
#  |    |    |    |-- audio_html_height: long (nullable = true)
#  |    |    |    |-- audio_html_width: long (nullable = true)
#  |    |    |    |-- author_icon: string (nullable = true)
#  |    |    |    |-- author_id: string (nullable = true)
#  |    |    |    |-- author_link: string (nullable = true)
#  |    |    |    |-- author_name: string (nullable = true)
#  |    |    |    |-- author_subname: string (nullable = true)
#  |    |    |    |-- channel_id: string (nullable = true)
#  |    |    |    |-- channel_name: string (nullable = true)
#  |    |    |    |-- color: string (nullable = true)
#  |    |    |    |-- fallback: string (nullable = true)
#  |    |    |    |-- fields: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- short: boolean (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- footer: string (nullable = true)
#  |    |    |    |-- footer_icon: string (nullable = true)
#  |    |    |    |-- from_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- image_bytes: long (nullable = true)
#  |    |    |    |-- image_height: long (nullable = true)
#  |    |    |    |-- image_url: string (nullable = true)
#  |    |    |    |-- image_width: long (nullable = true)
#  |    |    |    |-- indent: boolean (nullable = true)
#  |    |    |    |-- is_animated: boolean (nullable = true)
#  |    |    |    |-- is_msg_unfurl: boolean (nullable = true)
#  |    |    |    |-- mrkdwn_in: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- original_url: string (nullable = true)
#  |    |    |    |-- service_icon: string (nullable = true)
#  |    |    |    |-- service_name: string (nullable = true)
#  |    |    |    |-- service_url: string (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- thumb_height: long (nullable = true)
#  |    |    |    |-- thumb_url: string (nullable = true)
#  |    |    |    |-- thumb_width: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- title_link: string (nullable = true)
#  |    |    |    |-- ts: string (nullable = true)
#  |    |    |    |-- video_html: string (nullable = true)
#  |    |    |    |-- video_html_height: long (nullable = true)
#  |    |    |    |-- video_html_width: long (nullable = true)
#  |    |-- bot_id: string (nullable = true)
#  |    |-- client_msg_id: string (nullable = true)
#  |    |-- display_as_bot: boolean (nullable = true)
#  |    |-- edited: struct (nullable = true)
#  |    |    |-- ts: string (nullable = true)
#  |    |    |-- user: string (nullable = true)
#  |    |-- files: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- display_as_bot: boolean (nullable = true)
#  |    |    |    |-- editable: boolean (nullable = true)
#  |    |    |    |-- external_type: string (nullable = true)
#  |    |    |    |-- filetype: string (nullable = true)
#  |    |    |    |-- has_rich_preview: boolean (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- image_exif_rotation: long (nullable = true)
#  |    |    |    |-- is_external: boolean (nullable = true)
#  |    |    |    |-- is_public: boolean (nullable = true)
#  |    |    |    |-- mimetype: string (nullable = true)
#  |    |    |    |-- mode: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- original_h: long (nullable = true)
#  |    |    |    |-- original_w: long (nullable = true)
#  |    |    |    |-- permalink: string (nullable = true)
#  |    |    |    |-- permalink_public: string (nullable = true)
#  |    |    |    |-- pretty_type: string (nullable = true)
#  |    |    |    |-- public_url_shared: boolean (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- thumb_1024: string (nullable = true)
#  |    |    |    |-- thumb_1024_h: long (nullable = true)
#  |    |    |    |-- thumb_1024_w: long (nullable = true)
#  |    |    |    |-- thumb_160: string (nullable = true)
#  |    |    |    |-- thumb_360: string (nullable = true)
#  |    |    |    |-- thumb_360_h: long (nullable = true)
#  |    |    |    |-- thumb_360_w: long (nullable = true)
#  |    |    |    |-- thumb_480: string (nullable = true)
#  |    |    |    |-- thumb_480_h: long (nullable = true)
#  |    |    |    |-- thumb_480_w: long (nullable = true)
#  |    |    |    |-- thumb_64: string (nullable = true)
#  |    |    |    |-- thumb_720: string (nullable = true)
#  |    |    |    |-- thumb_720_h: long (nullable = true)
#  |    |    |    |-- thumb_720_w: long (nullable = true)
#  |    |    |    |-- thumb_80: string (nullable = true)
#  |    |    |    |-- thumb_800: string (nullable = true)
#  |    |    |    |-- thumb_800_h: long (nullable = true)
#  |    |    |    |-- thumb_800_w: long (nullable = true)
#  |    |    |    |-- thumb_960: string (nullable = true)
#  |    |    |    |-- thumb_960_h: long (nullable = true)
#  |    |    |    |-- thumb_960_w: long (nullable = true)
#  |    |    |    |-- timestamp: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url_private: string (nullable = true)
#  |    |    |    |-- url_private_download: string (nullable = true)
#  |    |    |    |-- user: string (nullable = true)
#  |    |    |    |-- username: string (nullable = true)
#  |    |-- hidden: boolean (nullable = true)
#  |    |-- icons: struct (nullable = true)
#  |    |    |-- image_36: string (nullable = true)
#  |    |    |-- image_48: string (nullable = true)
#  |    |    |-- image_72: string (nullable = true)
#  |    |-- latest_reply: string (nullable = true)
#  |    |-- replies: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ts: string (nullable = true)
#  |    |    |    |-- user: string (nullable = true)
#  |    |-- reply_count: long (nullable = true)
#  |    |-- reply_users: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- reply_users_count: long (nullable = true)
#  |    |-- subtype: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |    |-- thread_ts: string (nullable = true)
#  |    |-- ts: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- upload: boolean (nullable = true)
#  |    |-- upload_reply_to: string (nullable = true)
#  |    |-- user: string (nullable = true)
#  |    |-- username: string (nullable = true)
#  |-- subtype: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- thread_ts: string (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- ts: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- upload: boolean (nullable = true)
#  |-- upload_reply_to: string (nullable = true)
#  |-- user: string (nullable = true)
#  |-- username: string (nullable = true)

# %%
# what does the users schema look like?
users_df.printSchema()
# Out:
# root
#  |-- color: string (nullable = true)
#  |-- deleted: boolean (nullable = true)
#  |-- id: string (nullable = true)
#  |-- is_admin: boolean (nullable = true)
#  |-- is_app_user: boolean (nullable = true)
#  |-- is_bot: boolean (nullable = true)
#  |-- is_owner: boolean (nullable = true)
#  |-- is_primary_owner: boolean (nullable = true)
#  |-- is_restricted: boolean (nullable = true)
#  |-- is_ultra_restricted: boolean (nullable = true)
#  |-- name: string (nullable = true)
#  |-- profile: struct (nullable = true)
#  |    |-- always_active: boolean (nullable = true)
#  |    |-- api_app_id: string (nullable = true)
#  |    |-- avatar_hash: string (nullable = true)
#  |    |-- bot_id: string (nullable = true)
#  |    |-- display_name: string (nullable = true)
#  |    |-- display_name_normalized: string (nullable = true)
#  |    |-- email: string (nullable = true)
#  |    |-- fields: string (nullable = true)
#  |    |-- first_name: string (nullable = true)
#  |    |-- image_1024: string (nullable = true)
#  |    |-- image_192: string (nullable = true)
#  |    |-- image_24: string (nullable = true)
#  |    |-- image_32: string (nullable = true)
#  |    |-- image_48: string (nullable = true)
#  |    |-- image_512: string (nullable = true)
#  |    |-- image_72: string (nullable = true)
#  |    |-- image_original: string (nullable = true)
#  |    |-- is_custom_image: boolean (nullable = true)
#  |    |-- last_name: string (nullable = true)
#  |    |-- phone: string (nullable = true)
#  |    |-- real_name: string (nullable = true)
#  |    |-- real_name_normalized: string (nullable = true)
#  |    |-- skype: string (nullable = true)
#  |    |-- status_emoji: string (nullable = true)
#  |    |-- status_expiration: long (nullable = true)
#  |    |-- status_text: string (nullable = true)
#  |    |-- status_text_canonical: string (nullable = true)
#  |    |-- team: string (nullable = true)
#  |    |-- title: string (nullable = true)
#  |-- real_name: string (nullable = true)
#  |-- team_id: string (nullable = true)
#  |-- tz: string (nullable = true)
#  |-- tz_label: string (nullable = true)
#  |-- tz_offset: long (nullable = true)
#  |-- updated: long (nullable = true)

# %%
# channels?
channels_df.printSchema()
# Out:
# root
#  |-- created: string (nullable = true)
#  |-- creator: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- is_archived: boolean (nullable = true)
#  |-- is_general: boolean (nullable = true)
#  |-- members: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- name: string (nullable = true)
#  |-- pins: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- created: long (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- owner: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- user: string (nullable = true)
#  |-- purpose: struct (nullable = true)
#  |    |-- creator: string (nullable = true)
#  |    |-- last_set: string (nullable = true)
#  |    |-- value: string (nullable = true)
#  |-- topic: struct (nullable = true)
#  |    |-- creator: string (nullable = true)
#  |    |-- last_set: string (nullable = true)
#  |    |-- value: string (nullable = true)
